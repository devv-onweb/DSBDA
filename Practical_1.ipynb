# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-kote2005/DSBDA_Lab_Practical/blob/main/Practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('wheather_data.csv')

# %%
df.head()
# Out:
#                                             location  \
# 0  {'name': 'Abohar', 'region': 'Punjab', 'countr...
# 1  {'name': 'Adoni', 'region': 'Andhra Pradesh', ...
# 2  {'name': 'Agartala', 'region': 'Tripura', 'cou...
# 3  {'name': 'Agra', 'region': 'Uttar Pradesh', 'c...
# 4  {'name': 'Ahmedabad', 'region': 'Gujarat', 'co...
#
#                                              current error
# 0  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 1  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 2  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 3  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 4  {'last_updated_epoch': 1682924400, 'last_updat...   NaN

# %%
df.head(10)
# Out:
#                                             location  \
# 0  {'name': 'Abohar', 'region': 'Punjab', 'countr...
# 1  {'name': 'Adoni', 'region': 'Andhra Pradesh', ...
# 2  {'name': 'Agartala', 'region': 'Tripura', 'cou...
# 3  {'name': 'Agra', 'region': 'Uttar Pradesh', 'c...
# 4  {'name': 'Ahmedabad', 'region': 'Gujarat', 'co...
# 5  {'name': 'Ahmednagar', 'region': 'Gujarat', 'c...
# 6  {'name': 'Aizawl', 'region': 'Mizoram', 'count...
# 7  {'name': 'Ajmer', 'region': 'Rajasthan', 'coun...
# 8  {'name': 'Akola', 'region': 'Maharashtra', 'co...
# 9  {'name': 'Alappuzha', 'region': 'Kerala', 'cou...
#
#                                              current error
# 0  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 1  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 2  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 3  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 4  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# ...

# %%
df.tail()
# Out:
#                                               location  \
# 116  {'name': 'Guwahati', 'region': 'Assam', 'count...
# 117  {'name': 'Gwalior', 'region': 'Madhya Pradesh'...
# 118  {'name': 'Hajipur', 'region': 'Bihar', 'countr...
# 119  {'name': 'Haldia', 'region': 'West Bengal', 'c...
# 120  {'name': 'Hapur', 'region': 'Uttar Pradesh', '...
#
#                                                current error
# 116  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 117  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 118  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 119  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 120  {'last_updated_epoch': 1682924400, 'last_updat...   NaN

# %%
df.tail(10)
# Out:
#                                               location  \
# 111  {'name': 'Gulbarga', 'region': 'Karnataka', 'c...
# 112  {'name': 'Guna', 'region': 'Madhya Pradesh', '...
# 113  {'name': 'Guntakal', 'region': 'Andhra Pradesh...
# 114  {'name': 'Guntur', 'region': 'Andhra Pradesh',...
# 115  {'name': 'Gurgaon', 'region': 'Haryana', 'coun...
# 116  {'name': 'Guwahati', 'region': 'Assam', 'count...
# 117  {'name': 'Gwalior', 'region': 'Madhya Pradesh'...
# 118  {'name': 'Hajipur', 'region': 'Bihar', 'countr...
# 119  {'name': 'Haldia', 'region': 'West Bengal', 'c...
# 120  {'name': 'Hapur', 'region': 'Uttar Pradesh', '...
#
#                                                current error
# 111  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 112  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 113  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# 114  {'last_updated_epoch': 1682924400, 'last_updat...   NaN
# ...

# %%
df.shape
# Out:
# (121, 3)

# %%
df.describe()
# Out:
#                                                  location  \
# count                                                 117
# unique                                                116
# top     {'name': 'Durgapur', 'region': 'West Bengal', ...
# freq                                                    2
#
#                                                   current  \
# count                                                 117
# unique                                                111
# top     {'last_updated_epoch': 1682924400, 'last_updat...
# freq                                                    2
#
#                                                     error
# count                                                   4
# unique                                                  1
# top     {'code': 1006, 'message': 'No matching locatio...
# freq                                                    4

# %%
df.columns
# Out:
# Index(['location', 'current', 'error'], dtype='object')

# %%
df.isnull().sum()
# Out:
# location      4
# current       4
# error       117
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   location  117 non-null    object
#  1   current   117 non-null    object
#  2   error     4 non-null      object
# dtypes: object(3)
# memory usage: 3.0+ KB

# %%
df.dtypes
# Out:
# location    object
# current     object
# error       object
# dtype: object
