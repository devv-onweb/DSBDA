# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-kote2005/DSBDA/blob/main/DSBDA_2(A).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# %%
summary_stats = df.groupby('species').agg(['mean', 'median', 'min', 'max', 'std'])
# Out:
# /tmp/ipython-input-2914968289.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary_stats = df.groupby('species').agg(['mean', 'median', 'min', 'max', 'std'])

# %%
print(summary_stats)
# Out:
#            sepal length (cm)                            sepal width (cm)  \
#                         mean median  min  max       std             mean
# species
# setosa                 5.006    5.0  4.3  5.8  0.352490            3.428
# versicolor             5.936    5.9  4.9  7.0  0.516171            2.770
# virginica              6.588    6.5  4.9  7.9  0.635880            2.974
#
#                                       petal length (cm)                   \
#            median  min  max       std              mean median  min  max
# species
# setosa        3.4  2.3  4.4  0.379064             1.462   1.50  1.0  1.9
# versicolor    2.8  2.0  3.4  0.313798             4.260   4.35  3.0  5.1
# virginica     3.0  2.2  3.8  0.322497             5.552   5.55  4.5  6.9
#
#                      petal width (cm)
#                  std             mean median  min  max       std
# species
# setosa      0.173664            0.246    0.2  0.1  0.6  0.105386
# ...
