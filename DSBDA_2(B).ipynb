# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-kote2005/DSBDA/blob/main/DSBDA_2(B).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# %%
for species in df['species'].unique():
    print(f"\nStatistical details for {species.upper()}:")
    print(df[df['species'] == species].describe())
# Out:
# Statistical details for SETOSA:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count           50.00000         50.000000          50.000000
# mean             5.00600          3.428000           1.462000
# std              0.35249          0.379064           0.173664
# min              4.30000          2.300000           1.000000
# 25%              4.80000          3.200000           1.400000
# 50%              5.00000          3.400000           1.500000
# 75%              5.20000          3.675000           1.575000
# max              5.80000          4.400000           1.900000
#
#        petal width (cm)
# count         50.000000
# mean           0.246000
# std            0.105386
# min            0.100000
# 25%            0.200000
# 50%            0.200000
# 75%            0.300000
# max            0.600000
#
# Statistical details for VERSICOLOR:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# ...
